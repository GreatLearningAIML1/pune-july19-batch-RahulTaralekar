# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## K-Nearest-Neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x,y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h:X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1.Read the problem statement.
#
# 2.Get the dataset.
#
# 3.Explore the dataset.
#
# 4.Pre-processing of dataset.
#
# 5.Visualization
#
# 6.Transform the dataset for building machine learning model.
#
# 7.Split data into train, test set.
#
# 7.Build Model.
#
# 8.Apply the model.
#
# 9.Evaluate the model.
#
# 10.Finding Optimal K value
#
# 11.Repeat 7,8,9 steps.

# %% [markdown]
# ## Problem statement
#
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Attributes of the dataset:** https://archive.ics.uci.edu/ml/datasets/Iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Question 1
#
# Import the data set and print 10 random rows from the data set

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\rtaralekar\Documents\Day 4\Internal lab\Iris.csv")
df.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ## Question 2 - Estimating missing values
#
# *Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median) *

# %%
df.isnull().sum()
# Out:
# Sepal Length (in cm)    0
# Sepal Width in (cm)     0
# Petal length (in cm)    0
# Petal width (in cm)     0
# Class                   0
# dtype: int64

# %% [markdown]
# ## Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0to2).

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['class1'] = le.fit_transform(df['Class'])
le.classes_
df
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class  class1
# 0                    0.2     Iris-setosa       0
# 1                    0.2     Iris-setosa       0
# 2                    0.2     Iris-setosa       0
# 3                    0.2     Iris-setosa       0
# 4                    0.2     Iris-setosa       0
# 5                    0.4     Iris-setosa       0
# 6                    0.3     Iris-setosa       0
# 7                    0.2     Iris-setosa       0
# 8                    0.2     Iris-setosa       0
# 9                    0.1     Iris-setosa       0
# 10                   0.2     Iris-setosa       0
# 11                   0.2     Iris-setosa       0
# 12                   0.1     Iris-setosa       0
# 13                   0.1     Iris-setosa       0
# 14                   0.2     Iris-setosa       0
# 15                   0.4     Iris-setosa       0
# 16                   0.4     Iris-setosa       0
# 17                   0.3     Iris-setosa       0
# 18                   0.3     Iris-setosa       0
# 19                   0.3     Iris-setosa       0
# 20                   0.2     Iris-setosa       0
# 21                   0.4     Iris-setosa       0
# 22                   0.2     Iris-setosa       0
# 23                   0.5     Iris-setosa       0
# 24                   0.2     Iris-setosa       0
# 25                   0.2     Iris-setosa       0
# 26                   0.4     Iris-setosa       0
# 27                   0.2     Iris-setosa       0
# 28                   0.2     Iris-setosa       0
# 29                   0.2     Iris-setosa       0
# ..                   ...             ...     ...
# 120                  2.3  Iris-virginica       2
# 121                  2.0  Iris-virginica       2
# 122                  2.0  Iris-virginica       2
# 123                  1.8  Iris-virginica       2
# 124                  2.1  Iris-virginica       2
# 125                  1.8  Iris-virginica       2
# 126                  1.8  Iris-virginica       2
# 127                  1.8  Iris-virginica       2
# 128                  2.1  Iris-virginica       2
# 129                  1.6  Iris-virginica       2
# 130                  1.9  Iris-virginica       2
# 131                  2.0  Iris-virginica       2
# 132                  2.2  Iris-virginica       2
# 133                  1.5  Iris-virginica       2
# 134                  1.4  Iris-virginica       2
# 135                  2.3  Iris-virginica       2
# 136                  2.4  Iris-virginica       2
# 137                  1.8  Iris-virginica       2
# 138                  1.8  Iris-virginica       2
# 139                  2.1  Iris-virginica       2
# 140                  2.4  Iris-virginica       2
# 141                  2.3  Iris-virginica       2
# 142                  1.9  Iris-virginica       2
# 143                  2.3  Iris-virginica       2
# 144                  2.5  Iris-virginica       2
# 145                  2.3  Iris-virginica       2
# 146                  1.9  Iris-virginica       2
# 147                  2.0  Iris-virginica       2
# 148                  2.3  Iris-virginica       2
# 149                  1.8  Iris-virginica       2
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Question 4
#
# *Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.*

# %%
df.corr()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)              1.000000            -0.109369
# Sepal Width in (cm)              -0.109369             1.000000
# Petal length (in cm)              0.871754            -0.420516
# Petal width (in cm)               0.817954            -0.356544
# class1                            0.782561            -0.419446
#
#                       Petal length (in cm)  Petal width (in cm)    class1
# Sepal Length (in cm)              0.871754             0.817954  0.782561
# Sepal Width in (cm)              -0.420516            -0.356544 -0.419446
# Petal length (in cm)              1.000000             0.962757  0.949043
# Petal width (in cm)               0.962757             1.000000  0.956464
# class1                            0.949043             0.956464  1.000000

# %% [markdown]
# ## Question 5
#
# *Observe the independent variables variance and drop such variables having no variance or almost zero variance(variance < 0.1). They will be having almost no influence on the classification.*

# %%
df.var()
# Out:
# Sepal Length (in cm)    0.685694
# Sepal Width in (cm)     0.188004
# Petal length (in cm)    3.113179
# Petal width (in cm)     0.582414
# class1                  0.671141
# dtype: float64

# %% [markdown]
# ## Question 6
#
# *Plot the scatter matrix for all the variables.*

# %%
pd.plotting.scatter_matrix(df, figsize=(30, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000013758DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001069CAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001069C9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013F4FEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011020860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000110C9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010F83B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010F1F550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010F1F588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013F67828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000FAC11D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001110FB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FEA14E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000106EDE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001061A7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001065C198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001063EB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000106784A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010B27E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010B237B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000106AF160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010B8EAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001091C470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001090FDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010AC6780>]],
#       dtype=object)

# %% [markdown]
# ## Split the dataset into training and test sets
#
# ## Question 7
#
# *Split the dataset into training and test sets with 80-20 ratio.*

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns= "Class")
Y = df["Class"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# 130    Iris-virginica
# 131    Iris-virginica
# 132    Iris-virginica
# 133    Iris-virginica
# 134    Iris-virginica
# 135    Iris-virginica
# 136    Iris-virginica
# 137    Iris-virginica
# 138    Iris-virginica
# 139    Iris-virginica
# 140    Iris-virginica
# 141    Iris-virginica
# 142    Iris-virginica
# 143    Iris-virginica
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Class, Length: 150, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)

# %% [markdown]
# ## Question 8 - Model
#
# *Build the model and train and test on training and test sets respectively using **scikit-learn**. Print the Accuracy of the model with different values of **k=3,5,9**.*
#
# **Hint:** For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,Y_train)

from sklearn.metrics import accuracy_score

# %%
res = []
for i in range(1,30):
    if i==3 or i==5 or i==9:
        
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(X_train,Y_train)
        test_pred = knn.predict(X_test)
        print ("Test Acuracy of k = " + str(i)+ " is: " + str(accuracy_score(Y_test,test_pred)))
        res.append(accuracy_score(Y_test,test_pred))
        res_df=pd.DataFrame(res)
# Out:
# Test Acuracy of k = 3 is: 1.0
# Test Acuracy of k = 5 is: 1.0
# Test Acuracy of k = 9 is: 1.0

# %% [markdown]
# ## Question 9 - Finding Optimal value of k.
#
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the **optimal number of neighbours** from the above list using the Miss classification error

# %% [markdown]
# Hint:
#
# Misclassification error (MSE) = 1 - Test accuracy score. Calculated MSE for each model with neighbours = 1,3,5...19 and find the model with lowest MSE

# %%
res = []
for i in range(1,20):
    if i % 2 != 0 :
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(X_train,Y_train)
        test_pred = knn.predict(X_test)
        MSE = 1-accuracy_score(Y_test,test_pred) 
        print ("Misclassification error (MSE) = " + str(i)+ " is: " +str(MSE))
        res.append(MSE)
        mse_res_df=pd.DataFrame(res)
# Out:
# Misclassification error (MSE) = 1 is: 0.0
# Misclassification error (MSE) = 3 is: 0.0
# Misclassification error (MSE) = 5 is: 0.0
# Misclassification error (MSE) = 7 is: 0.0
# Misclassification error (MSE) = 9 is: 0.0
# Misclassification error (MSE) = 11 is: 0.0
# Misclassification error (MSE) = 13 is: 0.0
# Misclassification error (MSE) = 15 is: 0.0
# Misclassification error (MSE) = 17 is: 0.0
# Misclassification error (MSE) = 19 is: 0.0

# %% [markdown]
# ## Question 10
#
# *Plot misclassification error vs k (with k value on X-axis) using matplotlib.*

# %%
# %matplotlib inline
mse_res_df.plot()
