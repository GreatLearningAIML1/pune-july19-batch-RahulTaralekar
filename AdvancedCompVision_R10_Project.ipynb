# %% [markdown]
# # Instructions
# - Some parts of the code are already done for you
# - You need to execute all the cells
# - You need to add the code where ever you see `"#### Add your code here ####"`
# - Marks are mentioned along with the cells

# %% [markdown]
# # Face detection
# Task is to predict the boundaries(mask) around the face in a given image.

# %% [markdown]
# ## Dataset
# Faces in images marked with bounding boxes. Have around 500 images with around 1100 faces manually tagged via bounding box.

# %% [markdown]
# ### Mount Google drive if you are using google colab
# - We recommend using Google Colab as you can face memory issues and longer runtimes while running on local

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
tensorflow_version
# Out:
# Currently selected TF version: 2.x
# Available versions:
# * 1.x
# * 2.x

# %% [markdown]
# ### Change current working directory to project folder (1 mark)

# %%
pwd
# Out:
# '/content'

# %%
import os
os.chdir("/content/drive/My Drive/ACV")

# %% [markdown]
# ### Load the "images.npy" file (2 marks)
# - This file contains images with details of bounding boxes

# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from google.colab import drive
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Dense, Concatenate, UpSampling2D, Conv2D, Reshape, Conv2DTranspose, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.applications.mobilenet import preprocess_input

# %%
#data = #### Add your code here ####

# !wget https://olympus.greatlearning.in/courses/5661/files/765701/download?verifier=2p7lgWzrlorDxXZDQU48ChtLC9SpY8Jn8ih9snY3&wrap=1 -quite
# Out:
# /bin/bash: -quite: command not found
# --2020-04-25 07:23:15--  https://olympus.greatlearning.in/courses/5661/files/765701/download?verifier=2p7lgWzrlorDxXZDQU48ChtLC9SpY8Jn8ih9snY3
# Resolving olympus.greatlearning.in (olympus.greatlearning.in)... 52.2.201.214
# Connecting to olympus.greatlearning.in (olympus.greatlearning.in)|52.2.201.214|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://lms-uploads.s3-ap-southeast-1.amazonaws.com/account_1/attachments/539409/images.npy?response-content-disposition=attachment%3B%20filename%3D%22images%20%281%29.npy%22%3B%20filename%2A%3DUTF-8%27%27images%2520%25281%2529.npy&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIGH64THF2Z2BWILA%2F20200425%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Date=20200425T072315Z&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=2113fe42b1cf9d3d12e34ac573c148c5d8414955c40278f59f9b4f348f2f7499 [following]
# --2020-04-25 07:23:15--  https://lms-uploads.s3-ap-southeast-1.amazonaws.com/account_1/attachments/539409/images.npy?response-content-disposition=attachment%3B%20filename%3D%22images%20%281%29.npy%22%3B%20filename%2A%3DUTF-8%27%27images%2520%25281%2529.npy&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIGH64THF2Z2BWILA%2F20200425%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Date=20200425T072315Z&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=2113fe42b1cf9d3d12e34ac573c148c5d8414955c40278f59f9b4f348f2f7499
# Resolving lms-uploads.s3-ap-southeast-1.amazonaws.com (lms-uploads.s3-ap-southeast-1.amazonaws.com)... 52.219.40.123
# Connecting to lms-uploads.s3-ap-southeast-1.amazonaws.com (lms-uploads.s3-ap-southeast-1.amazonaws.com)|52.219.40.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1356868279 (1.3G) [binary/octet-stream]
# Saving to: ‘download?verifier=2p7lgWzrlorDxXZDQU48ChtLC9SpY8Jn8ih9snY3’
#
# download?verifier=2 100%[===================>]   1.26G  18.7MB/s    in 2m 17s
#
# 2020-04-25 07:25:32 (9.47 MB/s) - ‘download?verifier=2p7lgWzrlorDxXZDQU48ChtLC9SpY8Jn8ih9snY3’ saved [1356868279/1356868279]

# %%
data = np.load('images.npy',allow_pickle=True)

# %%
print('number of images in the given dataset is: ',data.shape[0])
# Out:
# number of images in the given dataset is:  409

# %% [markdown]
# ### Check one sample from the loaded "images.npy" file  (2 marks)

# %%
#### Add your code here ####
img_num=np.random.randint(0,data.shape[0])
plt.imshow(data[img_num][0])
print('Image index number: ',img_num)
# Out:
# Image index number:  356

# %% [markdown]
# ### Set image dimensions   (1 mark)
# - Initialize image height, image width with value: 224

# %%
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224

# %% [markdown]
# ### Create features and labels
# - Here feature is the image
# - The label is the mask
# - Images will be stored in "X_train" array
# - Masks will be stored in "masks" array

# %%
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input

masks = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH))
X_train = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH, 3))
for index in range(data.shape[0]):
    img = data[index][0]
    img = cv2.resize(img, dsize=(IMAGE_HEIGHT, IMAGE_WIDTH), interpolation=cv2.INTER_CUBIC)
    try:
      img = img[:, :, :3]
    except:
      continue
    X_train[index] = preprocess_input(np.array(img, dtype=np.float32))
    for i in data[index][1]:
        x1 = int(i["points"][0]['x'] * IMAGE_WIDTH)
        x2 = int(i["points"][1]['x'] * IMAGE_WIDTH)
        y1 = int(i["points"][0]['y'] * IMAGE_HEIGHT)
        y2 = int(i["points"][1]['y'] * IMAGE_HEIGHT)
        masks[index][y1:y2, x1:x2] = 1

# %% [markdown]
# ### Print the shape of X_train and mask array  (1 mark)

# %%
print (X_train.shape, masks.shape)
# Out:
# (409, 224, 224, 3) (409, 224, 224)

# %% [markdown]
# ### Print a sample image and image array

# %%
from matplotlib import pyplot
n = 356
print(X_train[n])
pyplot.imshow(X_train[n])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[-0.20784312 -0.13725489 -0.5529412 ]
#   [-0.27843136 -0.0745098  -0.60000002]
#   [ 0.02745104  0.19215691 -0.69411767]
#   ...
#   [-0.41176468 -0.11372548  0.05882359]
#   [-0.58431375 -0.34117645 -0.58431375]
#   [-0.71764708 -0.57647061 -0.54509807]]
#
#  [[-0.43529409 -0.33333331 -0.87450981]
#   [-0.45098037 -0.27843136 -0.6156863 ]
#   [-0.00392157  0.12941182 -0.49803919]
#   ...
#   [-0.40392154 -0.09803921  0.06666672]
#   [-0.67843139 -0.34117645 -0.35686272]
#   [-0.34901959 -0.08235294  0.10588241]]
#
#  [[-0.39607841 -0.24705881 -0.93725491]
#   [-0.67843139 -0.5529412  -0.7647059 ]
#   [-0.43529409 -0.33333331 -0.71764708]
#   ...
#   [-0.53725493 -0.23921567 -0.23921567]
#   [-0.3098039   0.09803927  0.24705887]
#   [-0.05098039  0.34901965  0.68627453]]
#
#  ...
#
#  [[ 0.78039217  0.05882359  0.50588238]
#   [ 0.7647059   0.14509809  0.53725493]
#   [ 0.77254903  0.26274514  0.58431375]
#   ...
#   [-1.          0.14509809  0.54509807]
#   [-0.97647059  0.12156868  0.50588238]
#   [-0.99215686  0.20000005  0.54509807]]
#
#  [[ 0.75686276 -0.00392157  0.4666667 ]
#   [ 0.74901962  0.12156868  0.51372552]
#   [ 0.78039217  0.29411769  0.6156863 ]
#   ...
#   [-1.          0.16078436  0.5529412 ]
#   [-0.97647059  0.10588241  0.49803925]
#   [-1.          0.13725495  0.51372552]]
#
#  [[ 0.79607844  0.1686275   0.56862748]
#   [ 0.86666667  0.19215691  0.60784316]
#   [ 0.78039217  0.0196079   0.45882356]
#   ...
#   [-0.99215686  0.10588241  0.47450984]
#   [-1.          0.13725495  0.50588238]
#   [-1.          0.082353    0.4666667 ]]]

# %%
pyplot.imshow(masks[n])

# %% [markdown]
# ## Create the model (10 marks)
# - Add MobileNet as model with below parameter values
#   - input_shape: IMAGE_HEIGHT, IMAGE_WIDTH, 3
#   - include_top: False
#   - alpha: 1.0
#   - weights: "imagenet"
# - Add UNET architecture layers
#   - This is the trickiest part of the project, you need to research and implement it correctly

# %%
ALPHA = 1
HEIGHT_CELLS = 28
WIDTH_CELLS = 28

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Concatenate, UpSampling2D, Conv2D, Reshape
from tensorflow.keras.models import Model


def create_model(trainable=True):

    alpha = 1.0
    model = MobileNet(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), include_top=False, alpha=alpha, weights='imagenet')
    
    for layer in model.layers:
        layer.trainable = trainable

    # Add all the UNET layers here

    # Using Mobilenet as Downscaling

    # Creating below layers for Upscaling
    block13 = model.get_layer("conv_pw_13_relu").output
    x = block13

    # Upsampling from block 13 to block 12
    x = Conv2DTranspose(int(1024 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)  
    block12 = model.get_layer("conv_pw_12_relu").output
    x = Concatenate()([x, block12])
    x = Conv2D(1024, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Upsampling from block 12 to block 11
    x = Conv2DTranspose(int(512 * alpha), (3, 3), strides=(2, 2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block11 = model.get_layer("conv_pw_11_relu").output
    x = Concatenate()([x, block11])
    x = Conv2D(512, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Upsampling from block 11 to block 10
    x = Conv2DTranspose(int(512 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block10 = model.get_layer("conv_pw_10_relu").output
    x = Concatenate()([x, block10])
    x = Conv2D(512, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x) 

    # Upsampling from block 10 to block 9
    x = Conv2DTranspose(int(512 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block9 = model.get_layer("conv_pw_9_relu").output
    x = Concatenate()([x, block9])
    x = Conv2D(512, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x) 

    # Upsampling from block 9 to block 8
    x = Conv2DTranspose(int(512 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block8 = model.get_layer("conv_pw_8_relu").output
    x = Concatenate()([x, block8])
    x = Conv2D(512, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)   

    # Upsampling from block 8 to block 7
    x = Conv2DTranspose(int(512 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block7 = model.get_layer("conv_pw_7_relu").output
    x = Concatenate()([x, block7])
    x = Conv2D(512, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x) 

    # Upsampling from block 7 to block 6
    x = Conv2DTranspose(int(512 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block6 = model.get_layer("conv_pw_6_relu").output
    x = Concatenate()([x, block6])
    x = Conv2D(512, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)   

    # Upsampling from block 6 to block 5
    x = Conv2DTranspose(int(256 * alpha), (3, 3), strides=(2, 2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block5 = model.get_layer("conv_pw_5_relu").output
    x = Concatenate()([x, block5])
    x = Conv2D(256, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x) 

    # Upsampling from block 5 to block 4
    x = Conv2DTranspose(int(256 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block4 = model.get_layer("conv_pw_4_relu").output
    x = Concatenate()([x, block4])
    x = Conv2D(256, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Upsampling from block 4 to block 3
    x = Conv2DTranspose(int(128 * alpha), (3, 3), strides=(2, 2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block3 = model.get_layer("conv_pw_3_relu").output
    x = Concatenate()([x, block3])
    x = Conv2D(128, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Upsampling from block 3 to block 2
    x = Conv2DTranspose(int(128 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block2 = model.get_layer("conv_pw_2_relu").output
    x = Concatenate()([x, block2])
    x = Conv2D(128, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Upsampling from block 2 to block 1
    x = Conv2DTranspose(int(64 * alpha), (3, 3), strides=(2, 2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    block1 = model.get_layer("conv_pw_1_relu").output
    x = Concatenate()([x, block1])
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Upsampling from block 1 to conv 1
    x = Conv2DTranspose(int(32 * alpha), (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    conv1 = model.get_layer("conv1_relu").output
    x = Concatenate()([x, conv1])
    x = Conv2D(32, (1, 1), strides=(1, 1), padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2DTranspose(int(32 * alpha), (3, 3), strides=(2, 2), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    

    # Adding below layer for final output
    x = Conv2D(1, kernel_size=1, activation="sigmoid")(x)
    x = Reshape((224, 224))(x)

    return Model(inputs=model.input, outputs=x)

# %% [markdown]
# ### Call the create_model function

# %%
# Give trainable=False as argument, if you want to freeze lower layers for fast training (but low accuracy)
model = create_model()

# Print summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 112, 112, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 112, 112, 32) 288         conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 112, 112, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (ReLU)           (None, 112, 112, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 112, 112, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 112, 112, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (ReLU)           (None, 112, 112, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 113, 113, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 56, 56, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 56, 56, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (ReLU)           (None, 56, 56, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 56, 56, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 56, 56, 128)  1152        conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 56, 56, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 57, 57, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 28, 28, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (ReLU)           (None, 28, 28, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 28, 28, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 28, 28, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 29, 29, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (ReLU)           (None, 14, 14, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 14, 14, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_11 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_11[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 15, 15, 512)  0           conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 7, 7, 512)    4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 7, 7, 512)    2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (ReLU)          (None, 7, 7, 512)    0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 7, 7, 1024)   524288      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 7, 7, 1024)   9216        conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_13 (Conv2D)             (None, 7, 7, 1024)   1048576     conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_13[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 7, 7, 1024)   9437184     conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 7, 7, 1024)   4096        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 7, 7, 1024)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 2048)   0           activation[0][0]
#                                                                  conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 7, 7, 1024)   2097152     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 1024)   4096        conv2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 7, 7, 1024)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 512)  4718592     activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 512)  2048        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1024) 0           activation_2[0][0]
#                                                                  conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 512)  524288      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 14, 14, 512)  2359296     activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 512)  2048        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 512)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 1024) 0           activation_4[0][0]
#                                                                  conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 512)  524288      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 14, 14, 512)  2359296     activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 512)  2048        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 1024) 0           activation_6[0][0]
#                                                                  conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 512)  524288      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 14, 14, 512)  2359296     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 512)  2048        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 1024) 0           activation_8[0][0]
#                                                                  conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 512)  524288      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 14, 14, 512)  2359296     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 512)  2048        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 1024) 0           activation_10[0][0]
#                                                                  conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 512)  524288      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 512)  2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 14, 14, 512)  2359296     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 512)  2048        conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 1024) 0           activation_12[0][0]
#                                                                  conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 14, 14, 512)  524288      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 28, 28, 256)  1179648     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 256)  1024        conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 512)  0           activation_14[0][0]
#                                                                  conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  131072      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 28, 28, 256)  589824      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 512)  0           activation_16[0][0]
#                                                                  conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  131072      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 56, 56, 128)  294912      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 56, 128)  512         conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 56, 56, 256)  0           activation_18[0][0]
#                                                                  conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  32768       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 56, 56, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 56, 56, 128)  147456      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 56, 56, 128)  512         conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 56, 56, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 56, 56, 256)  0           activation_20[0][0]
#                                                                  conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 128)  32768       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 56, 56, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 56, 56, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 112, 112, 64) 73728       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 112, 112, 64) 256         conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 112, 112, 64) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 112, 112, 128 0           activation_22[0][0]
#                                                                  conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 112, 112, 64) 8192        concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 112, 112, 64) 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 112, 112, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 112, 112, 32) 18432       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 112, 112, 32) 128         conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 112, 112, 32) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 112, 112, 64) 0           activation_24[0][0]
#                                                                  conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 32) 2048        concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 112, 112, 32) 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 112, 112, 32) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 224, 224, 32) 9216        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 224, 224, 32) 128         conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 224, 224, 32) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 224, 224, 1)  33          activation_26[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 224, 224)     0           conv2d_13[0][0]
# ==================================================================================================
# Total params: 37,114,977
# Trainable params: 37,073,185
# Non-trainable params: 41,792
# __________________________________________________________________________________________________

# %% [markdown]
# ### Define dice coefficient function (5 marks)
# - Create a function to calculate dice coefficient

# %%
def dice_coefficient(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)

    return numerator / (denominator + tf.keras.backend.epsilon())

# %% [markdown]
# ### Define loss

# %%
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.backend import log, epsilon
def loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - log(dice_coefficient(y_true, y_pred) + epsilon())

# %% [markdown]
# ### Compile the model (2 marks)
# - Complie the model using below parameters
#   - loss: use the loss function defined above
#   - optimizers: use Adam optimizer
#   - metrics: use dice_coefficient function defined above

# %%
model.compile(optimizer='Adam',loss=loss,metrics=[dice_coefficient])

# %% [markdown]
# ### Define checkpoint and earlystopping

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
checkpoint = ModelCheckpoint("model-{loss:.2f}.h5", monitor="loss", verbose=1, save_best_only=True,
                             save_weights_only=True, mode="min", period=1)
stop = EarlyStopping(monitor="loss", patience=5, mode="min")
reduce_lr = ReduceLROnPlateau(monitor="loss", factor=0.2, patience=5, min_lr=1e-6, verbose=1, mode="min")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ### Fit the model (2 marks)
# - Fit the model using below parameters
#   - epochs: you can decide
#   - batch_size: 1
#   - callbacks: checkpoint, reduce_lr, stop

# %%
model.fit(x=X_train, y=masks, epochs=16, batch_size=1, callbacks=[checkpoint, reduce_lr, stop])
# Out:
# Epoch 1/16
# 409/409 [==============================] - ETA: 0s - loss: 1.2384 - dice_coefficient: 0.4628
# Epoch 00001: loss improved from inf to 1.23838, saving model to model-1.24.h5
# 409/409 [==============================] - 50s 121ms/step - loss: 1.2384 - dice_coefficient: 0.4628 - lr: 0.0010
# Epoch 2/16
# 409/409 [==============================] - ETA: 0s - loss: 0.9213 - dice_coefficient: 0.5685
# Epoch 00002: loss improved from 1.23838 to 0.92128, saving model to model-0.92.h5
# 409/409 [==============================] - 50s 121ms/step - loss: 0.9213 - dice_coefficient: 0.5685 - lr: 0.0010
# Epoch 3/16
# 409/409 [==============================] - ETA: 0s - loss: 0.8339 - dice_coefficient: 0.6022
# Epoch 00003: loss improved from 0.92128 to 0.83393, saving model to model-0.83.h5
# 409/409 [==============================] - 49s 121ms/step - loss: 0.8339 - dice_coefficient: 0.6022 - lr: 0.0010
# Epoch 4/16
# 409/409 [==============================] - ETA: 0s - loss: 0.7561 - dice_coefficient: 0.6344
# Epoch 00004: loss improved from 0.83393 to 0.75613, saving model to model-0.76.h5
# 409/409 [==============================] - 49s 121ms/step - loss: 0.7561 - dice_coefficient: 0.6344 - lr: 0.0010
# Epoch 5/16
# 409/409 [==============================] - ETA: 0s - loss: 0.7118 - dice_coefficient: 0.6491
# Epoch 00005: loss improved from 0.75613 to 0.71182, saving model to model-0.71.h5
# 409/409 [==============================] - 49s 121ms/step - loss: 0.7118 - dice_coefficient: 0.6491 - lr: 0.0010
# Epoch 6/16
# 409/409 [==============================] - ETA: 0s - loss: 0.6622 - dice_coefficient: 0.6707
# Epoch 00006: loss improved from 0.71182 to 0.66221, saving model to model-0.66.h5
# 409/409 [==============================] - 50s 121ms/step - loss: 0.6622 - dice_coefficient: 0.6707 - lr: 0.0010
# Epoch 7/16
# 409/409 [==============================] - ETA: 0s - loss: 0.6058 - dice_coefficient: 0.6946
# Epoch 00007: loss improved from 0.66221 to 0.60582, saving model to model-0.61.h5
# 409/409 [==============================] - 49s 120ms/step - loss: 0.6058 - dice_coefficient: 0.6946 - lr: 0.0010
# Epoch 8/16
# 409/409 [==============================] - ETA: 0s - loss: 0.5353 - dice_coefficient: 0.7235
# Epoch 00008: loss improved from 0.60582 to 0.53531, saving model to model-0.54.h5
# 409/409 [==============================] - 49s 121ms/step - loss: 0.5353 - dice_coefficient: 0.7235 - lr: 0.0010
# Epoch 9/16
# 409/409 [==============================] - ETA: 0s - loss: 0.4737 - dice_coefficient: 0.7548
# Epoch 00009: loss improved from 0.53531 to 0.47367, saving model to model-0.47.h5
# 409/409 [==============================] - 50s 121ms/step - loss: 0.4737 - dice_coefficient: 0.7548 - lr: 0.0010
# Epoch 10/16
# 409/409 [==============================] - ETA: 0s - loss: 0.4433 - dice_coefficient: 0.7694
# Epoch 00010: loss improved from 0.47367 to 0.44329, saving model to model-0.44.h5
# 409/409 [==============================] - 50s 121ms/step - loss: 0.4433 - dice_coefficient: 0.7694 - lr: 0.0010
# Epoch 11/16
# 409/409 [==============================] - ETA: 0s - loss: 0.4538 - dice_coefficient: 0.7664
# Epoch 00011: loss did not improve from 0.44329
# 409/409 [==============================] - 48s 119ms/step - loss: 0.4538 - dice_coefficient: 0.7664 - lr: 0.0010
# Epoch 12/16
# 409/409 [==============================] - ETA: 0s - loss: 0.3946 - dice_coefficient: 0.7933
# Epoch 00012: loss improved from 0.44329 to 0.39461, saving model to model-0.39.h5
# 409/409 [==============================] - 49s 121ms/step - loss: 0.3946 - dice_coefficient: 0.7933 - lr: 0.0010
# Epoch 13/16
# 409/409 [==============================] - ETA: 0s - loss: 0.3440 - dice_coefficient: 0.8200
# Epoch 00013: loss improved from 0.39461 to 0.34399, saving model to model-0.34.h5
# 409/409 [==============================] - 49s 121ms/step - loss: 0.3440 - dice_coefficient: 0.8200 - lr: 0.0010
# Epoch 14/16
# 409/409 [==============================] - ETA: 0s - loss: 0.3038 - dice_coefficient: 0.8405
# Epoch 00014: loss improved from 0.34399 to 0.30383, saving model to model-0.30.h5
# 409/409 [==============================] - 50s 122ms/step - loss: 0.3038 - dice_coefficient: 0.8405 - lr: 0.0010
# Epoch 15/16
# 409/409 [==============================] - ETA: 0s - loss: 0.2883 - dice_coefficient: 0.8500
# Epoch 00015: loss improved from 0.30383 to 0.28826, saving model to model-0.29.h5
# 409/409 [==============================] - 50s 121ms/step - loss: 0.2883 - dice_coefficient: 0.8500 - lr: 0.0010
# Epoch 16/16
# 409/409 [==============================] - ETA: 0s - loss: 0.2901 - dice_coefficient: 0.8499
# Epoch 00016: loss did not improve from 0.28826
# 409/409 [==============================] - 48s 118ms/step - loss: 0.2901 - dice_coefficient: 0.8499 - lr: 0.0010

# %% [markdown]
# ### Get the predicted mask for a sample image   (3 marks)

# %%
n = 356
sample_image = X_train[n]
pyplot.imshow(sample_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Impose the mask on the image (3 marks)

# %%
resized_sample_image = np.expand_dims(sample_image, axis=0)
mask = model.predict(resized_sample_image)
mask = np.reshape(mask, (224,224))
pyplot.imshow(mask)

# %%
masked = np.ma.masked_where(mask < 0.1, mask)

pyplot.figure()
pyplot.subplot(1,2,1)
pyplot.imshow(sample_image)
pyplot.subplot(1,2,2)
pyplot.imshow(sample_image)
pyplot.imshow(masked, alpha=0.8)
pyplot.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
